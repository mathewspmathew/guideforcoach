# %%
import os
import sys
sys.path.append(os.path.abspath(".."))
from src.model import SimilarityEngine
print("It works manually!")
# Out:
# It works manually!

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))
import src
print(src.__file__)
# This should point to your local /root/src/__init__.py
# Out:
# /home/mathe/Documents/learn/week47/guideforcoach/src/__init__.py

# %%
import os
import sys
sys.path.append(os.path.abspath(".."))
from src.model import SimilarityEngine
from src.config import DB_PATH

# print(DB_PATH)

ml_engine = SimilarityEngine()

result = ml_engine.inference("Matthis Abline")

# if "error" in result:
#     # Fallback if player not found
#     print ("error")

# # 2. Return the list of matches to the State
# print (result)
# if not os.path.exists(DB_PATH):
#     print('yes')
print(result)
# Out:
# {'error': 'Model not trained yet.'}
